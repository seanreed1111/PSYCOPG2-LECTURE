# %%
# !conda install sqlalchemy -y
# Out:
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/seanreed1/miniconda3
#
#   added / updated specs:
#     - sqlalchemy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2020.6.20          |   py37h2987424_2         151 KB  conda-forge
#     conda-4.8.5                |   py37h2987424_2         3.0 MB  conda-forge
#     sqlalchemy-1.3.20          |   py37h60d8a13_0         1.8 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         5.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   sqlalchemy         conda-forge/osx-64::sqlalchemy-1.3.20-py37h60d8a13_0
#
# The following packages will be UPDATED:
#
#   certifi                          2020.6.20-py37hc8dfbb8_0 --> 2020.6.20-py37h2987424_2
# ...

# %%
import pandas as pd
from sqlalchemy import create_engine

# replace with your own settings
DATABASE = {
        'NAME': 'jupyterdb',
        'USER': 'seanreed1',
        'PASSWORD':None,
        'HOST': 'localhost',
        'PORT': 5432,
}

# %%
engine_string = "postgresql+psycopg2://{user}:{password}@{host}:{port}/{database}".format(
    user = DATABASE['USER'],
    password = DATABASE['PASSWORD'],
    host = DATABASE['HOST'],
    port = DATABASE['PORT'],
    database = DATABASE['NAME'],
)
engine_string
# Out:
# 'postgresql+psycopg2://seanreed1:None@localhost:5432/jupyterdb'

# %%
# construct an engine connection string

engine_string = "postgresql+psycopg2://{user}:{password}@{host}:{port}/{database}".format(
    user = DATABASE['USER'],
    password = DATABASE['PASSWORD'],
    host = DATABASE['HOST'],
    port = DATABASE['PORT'],
    database = DATABASE['NAME'],
)

# create sqlalchemy engine
engine = create_engine(engine_string)

# read a table from database into pandas dataframe, replace "tablename" with your table name
df = pd.read_sql_table('psycopg_test',engine)

# %%
df
# Out:
#     id               name                        email
# 0    1               sean      sean.reed@galvanize.com
# 1    2     Bonnie Pacheco            ukramer@yahoo.com
# 2    3     Bonnie Pacheco            ukramer@yahoo.com
# 3    4     Bonnie Pacheco            ukramer@yahoo.com
# 4    5  Daniel Richardson       benjamin41@johnson.net
# 5    6       Shaun Vaughn        kimberly11@dixon.info
# 6    7     Erin Whitehead          karen82@hotmail.com
# 7    8       Debra Castro           amanda55@yahoo.com
# 8    9   Jeffrey Thompson              ehaas@yahoo.com
# 9   10      Aaron Jackson       bsmith@nash-garcia.com
# 10  11       Bianca Mcgee      matthewbarber@gmail.com
# 11  12       Aaron Murphy       xvilla@bell-miller.com
# 12  13  Nicholas Martinez            fcastro@gmail.com
# 13  14        Alan Harris       baileyjoseph@gmail.com
# 14  15     Mikayla Bailey            bwright@wells.net
# 15  16      Jessica Brown             hsmith@lewis.org
# ...

# %%
df = pd.read_sql_table('psycopg_test',engine)
df
# Out:
# ---------------------------------------------------------------------------
# InsufficientPrivilege                     Traceback (most recent call last)
# ~/miniconda/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1265                 if not evt_handled:
# -> 1266                     self.dialect.do_execute_no_params(
#    1267                         cursor, statement, context
#
# ~/miniconda/lib/python3.8/site-packages/sqlalchemy/engine/default.py in do_execute_no_params(self, cursor, statement, context)
#     595     def do_execute_no_params(self, cursor, statement, context=None):
# --> 596         cursor.execute(statement)
#     597
#
# InsufficientPrivilege: permission denied for table psycopg_test
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# ...

# %%
df = pd.read_sql_table('cars',engine)
df
# Out:
#    id        name   price
# 0   1        Audi   52642
# 1   2    Mercedes   57127
# 2   3       Skoda    9000
# 3   4       Volvo   29000
# 4   5     Bentley  350000
# 5   6     Citroen   21000
# 6   7      Hummer   41400
# 7   8  Volkswagen   21600

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      8 non-null      int64
#  1   name    8 non-null      object
#  2   price   8 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 320.0+ bytes

# %%
engine = create_engine(engine_string)

# %%
q = "SELECT * FROM cars WHERE PRICE > 22000"

df2 = pd.read_sql_query(q, engine)
df2
# Out:
#    id      name   price
# 0   1      Audi   52642
# 1   2  Mercedes   57127
# 2   4     Volvo   29000
# 3   5   Bentley  350000
# 4   7    Hummer   41400

# %%
# engine = create_engine(engine_string)
q = "SELECT * FROM cars WHERE id < 4"
df3 = pd.read_sql_query(q, engine)
df3
# Out:
#    id      name  price
# 0   1      Audi  52642
# 1   2  Mercedes  57127
# 2   3     Skoda   9000

# %%
engine.dispose() # can also use a context manager

# %% [markdown]
# ## more details on pd.read_sql_query

# %%
pd.read_sql_table??
# Out:
# Signature:
# pd.read_sql_table(
#     table_name,
#     con,
#     schema=None,
#     index_col=None,
#     coerce_float=True,
#     parse_dates=None,
#     columns=None,
#     chunksize=None,
# )
# Source:
# def read_sql_table(
#     table_name,
#     con,
#     schema=None,
#     index_col=None,
#     coerce_float=True,
#     parse_dates=None,
#     columns=None,
#     chunksize=None,
# ):
#     """
#     Read SQL database table into a DataFrame.
#
#     Given a table name and a SQLAlchemy connectable, returns a DataFrame.
#     This function does not support DBAPI connections.
#
#     Parameters
#     ----------
#     table_name : str
#         Name of SQL table in database.
#     con : SQLAlchemy connectable or str
#         A database URI could be provided as as str.
#         SQLite DBAPI connection mode not supported.
#     schema : str, default None
#         Name of SQL schema in database to query (if database flavor
# ...

# %% [markdown]
# ## more details on pd.read_sql_query

# %%
pd.read_sql_query??
# Out:
# Signature:
# pd.read_sql_query(
#     sql,
#     con,
#     index_col=None,
#     coerce_float=True,
#     params=None,
#     parse_dates=None,
#     chunksize=None,
# )
# Source:
# def read_sql_query(
#     sql,
#     con,
#     index_col=None,
#     coerce_float=True,
#     params=None,
#     parse_dates=None,
#     chunksize=None,
# ):
#     """
#     Read SQL query into a DataFrame.
#
#     Returns a DataFrame corresponding to the result set of the query
#     string. Optionally provide an `index_col` parameter to use one of the
#     columns as the index, otherwise default integer index will be used.
#
#     Parameters
#     ----------
#     sql : str SQL query or SQLAlchemy Selectable (select or text object)
#         SQL query to be executed.
#     con : SQLAlchemy connectable(engine/connection), database str URI,
#         or sqlite3 DBAPI2 connection
#         Using SQLAlchemy makes it possible to use any DB supported by that
#         library.
# ...

# %% [markdown]
# Resources: https://gist.github.com/kunanit/eb0723eef653788395bb41c661c1fa86
